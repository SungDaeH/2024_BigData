# %% [markdown]
# # 30918_황성대_0627_7

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')

sales = [1,5,7,3,7]
month = ['mar', 'apr', 'may', 'jun', 'jul']

plt.figure(dpi=100)

plt.title('월별 판매 실적')
plt.plot(month, sales, color='m', label='단위:계수')


plt.legend(loc = 'lower right')
plt.xlabel("월")
plt.ylabel('매출')

plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')

sales = [1,5,7,3,7]
month = [3,4,5,6,7]

plt.title('월별 판매 실적')
plt.bar(month, sales, color='b')

plt.xlabel('월')
plt.ylabel('매출')
# Out:
# Text(0, 0.5, '매출')

# %%
import random
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')

a = []
for i in range(10):
    a.append(random.randint(1,10))
print(a)

plt.title("히스토그램 그리기")
plt.hist(a)
plt.show()
# Out:
# [7, 7, 2, 6, 7, 7, 1, 10, 5, 6]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family="Malgun Gothic")

b_type = [25, 19, 37, 11]
b_name = ['A형', 'B형', 'O형', 'AB형']

plt.title('혈액형 분포')

plt.pie(b_type, labels=b_name, autopct = '%1.1f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
import random
plt.rc('font', family='Malgun Gothic')

height = []
weight = []

for i in range(100):
    height.append(random.randint(100,200))
    weight.append(random.randint(20,100))
    
plt.title('키와 몸무게의 상관관계')

plt.scatter(height, weight, c=height, cmap="RdPu")
plt.xlabel('키')
plt.ylabel('몸무게')
plt.colorbar(label='키')

plt.show()

# %%
import matplotlib.pyplot as plt
import random
plt.rc('font', family='Malgun Gothic')

height, weight, score = [],[],[]

for i in range(100):
    height.append(random.randint(100,200))
    weight.append(random.randint(20, 100))
    score.append(random.randint(1, 1000))
    
plt.scatter(height, weight, s = score, c=score, cmap="rainbow", alpha = 0.7)

plt.title('키와 몸무게의 상관관계')
plt.colorbar(label='체육 점수 실기')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')

singer = ['A','B','C', 'D', 'E']
week1 = [42,58,19,92,84]
week2 = [53,52,48,98,73]

for i in range(len(week1)):
    week1[i] = -week1[i]
    
plt.rcParams['axes.unicode_minus'] = False

plt.title('오디션 프로그램 득표 현황')
plt.barh(singer, week1, label='첫째주', color = 'hotpink')
plt.barh(singer, week2, label = '둘째주', color = 'royalblue')
plt.legend()
plt.show()
