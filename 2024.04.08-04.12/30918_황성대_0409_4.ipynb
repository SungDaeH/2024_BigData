# %% [markdown]
# # 30918_황성대_0409_4

# %% [markdown]
# ## 조건문으로 간단한 프로그램 만들기

# %%
# 목욕탕에 가면 미성년자는 6000원 성안은 15000원
# 나이를 입력받아서 구분하는 프로그램을 만들어 보자

age = int(input())

if age < 20:
    print("미성년자는 6000원입니다.")
else :
    print("성인은 15000원입니다.")
# Out:
# 22
# 성인은 15000원입니다.

# %%
# 나이 구분
# 금액 구분
price = 0
# 1단계
age = int(input("나이를 입력하시오 : "))

if age < 20 :
    print("미성년자는 6000원입니다.")
    price= 6000
else :
    print("성인은 15000원입니다,")
    price = 15000
    
# 2단계 투입금액을 입력받아 입장료와 비교하기

price_input = int(input("금액을 투입해 주세요 --> : "))
if price_input < price:
    print(f"{price-price_input}원 더 내셔야 합니다")
elif price_input > price:
    print(f"{price_input-price}원 거슬러 드리겠습니다.")
else :
    print(f"즐겁게 이용하십시오.")
# Out:
# 나이를 입력하시오 : 10
# 미성년자는 6000원입니다.
# 금액을 투입해 주세요 --> : 6000
# 즐겁게 이용하십시오.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
food = input("어떤 메뉴가 궁금하신가요? : ")

if food == "라면" :
    print("기본 라면 : 3500원")
    print("떡라면 : 4000원")
    print("만두라면 : 4000원")
elif food == "김밥":
    print("야채김밥 : 3000원")
    print("참치김밥 : 4000원")
    print("꼬마김밥 : 2000원")
else:
    print("올바른 메뉴를 입력해 주세요")
# Out:
# 어떤 메뉴가 궁금하신가요? : ㄴ
# 올바른 메뉴를 입력해 주세요
